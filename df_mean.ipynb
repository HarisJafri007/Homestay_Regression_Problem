# %% [markdown]
# This Data Frame is a transformed version of Original Data Frame with Null Values replaced with Mean and we have not treated outliers!

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.style

# %%
file_path = 'df_mean.csv'
df = pd.read_csv(file_path)
df
# Out:
#        accommodates  bathrooms  cleaning_fee  review_scores_rating  bedrooms  \
# 0               3.0        1.0           1.0            100.000000       1.0
# 1               7.0        1.0           1.0             93.000000       3.0
# 2               5.0        1.0           1.0             92.000000       1.0
# 3               4.0        1.0           1.0             93.202041       2.0
# 4               2.0        1.0           1.0             40.000000       0.0
# ...             ...        ...           ...                   ...       ...
# 54112           2.0        1.0           1.0            100.000000       1.0
# 54113           4.0        2.0           1.0             93.000000       2.0
# 54114           5.0        1.0           1.0             94.000000       2.0
# 54115           2.0        1.0           1.0             93.202041       0.0
# 54116           4.0        1.0           0.0             96.000000       1.0
#
# ...

# %% [markdown]
# Let us watch the Correlation between different features!

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(),annot=True)
plt.show()

# %% [markdown]
# Now we are going to seperate our data frame into two parts. X containing all Independent Variables and y containing the Target Variable.

# %%
X = df.drop('log_price',axis=1)

# %%
X.head()
# Out:
#    accommodates  bathrooms  cleaning_fee  review_scores_rating  bedrooms  \
# 0           3.0        1.0           1.0            100.000000       1.0
# 1           7.0        1.0           1.0             93.000000       3.0
# 2           5.0        1.0           1.0             92.000000       1.0
# 3           4.0        1.0           1.0             93.202041       2.0
# 4           2.0        1.0           1.0             40.000000       0.0
#
#    beds  room_type_Entire home/apt  room_type_Private room  \
# 0   1.0                       True                   False
# 1   3.0                       True                   False
# 2   3.0                       True                   False
# 3   2.0                       True                   False
# 4   1.0                       True                   False
#
#    room_type_Shared room  cancellation_policy_flexible  \
# 0                  False                         False
# 1                  False                         False
# ...

# %%
y = df[['log_price']]

# %%
y.head()
# Out:
#    log_price
# 0   5.010635
# 1   5.129899
# 2   4.976734
# 3   6.620073
# 4   4.744932

# %% [markdown]
# We have successfully divided the Data Frame into Independent and Target Variables. Now we shall divide the Data Frame into Test and Train!

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3,random_state=1)

# %%
X_train
# Out:
#        accommodates  bathrooms  cleaning_fee  review_scores_rating  bedrooms  \
# 25136           7.0        1.0           0.0            100.000000       1.0
# 6288            1.0        2.0           0.0             99.000000       1.0
# 36561           2.0        1.0           0.0             80.000000       1.0
# 2034           16.0        1.0           1.0            100.000000       0.0
# 21668           3.0        1.0           0.0             93.202041       1.0
# ...             ...        ...           ...                   ...       ...
# 50057           2.0        1.0           1.0             90.000000       1.0
# 32511           6.0        1.0           1.0             97.000000       2.0
# 5192            4.0        1.0           1.0             98.000000       1.0
# 12172           3.0        1.0           1.0             98.000000       1.0
# 33003           1.0        1.0           0.0            100.000000       1.0
#
# ...

# %%
X_test
# Out:
#        accommodates  bathrooms  cleaning_fee  review_scores_rating  bedrooms  \
# 33694           4.0   2.000000           1.0            100.000000       2.0
# 8930            3.0   1.000000           1.0             88.000000       1.0
# 26368           1.0   1.000000           1.0            100.000000       1.0
# 32595           3.0   1.000000           1.0             54.000000       0.0
# 14713           3.0   1.000000           0.0            100.000000       1.0
# ...             ...        ...           ...                   ...       ...
# 19791           2.0   1.000000           0.0             90.000000       1.0
# 18946           1.0   1.304829           1.0             80.000000       1.0
# 8845            4.0   1.000000           0.0             93.202041       1.0
# 4512            4.0   1.500000           1.0             98.000000       3.0
# 53746          12.0   1.000000           1.0             89.000000       3.0
#
# ...

# %% [markdown]
# This clearly shows that our model has been successfully divided into Train Data and Test Data!

# %%
round(54117*0.3)
# Out:
# 16235

# %% [markdown]
# Let us import some Machine Learning Libraries!

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor

# %% [markdown]
# ### Linear Regression

# %%
regression_model = LinearRegression()
regression_model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Predicting y values using the test set
y_predicted = regression_model.predict(X_test)

# Ensure y_test and y_predicted are arrays
y_test = y_test.values.flatten()
y_predicted = y_predicted.flatten()

# Comparing y_predicted to y_test
comparison = pd.DataFrame({'Actual': y_test, 'Predicted': y_predicted})
print(comparison.head())
# Out:
#      Actual  Predicted
# 0  5.402677   5.407017
# 1  4.867534   4.941501
# 2  4.174387   3.767978
# 3  4.779123   4.479547
# 4  4.787492   5.110028

# %%
print(comparison.head(10))
# Out:
#      Actual  Predicted
# 0  5.402677   5.407017
# 1  4.867534   4.941501
# 2  4.174387   3.767978
# 3  4.779123   4.479547
# 4  4.787492   5.110028
# 5  5.075174   4.277963
# 6  4.369448   4.335927
# 7  4.584967   5.375565
# 8  4.828314   4.696376
# 9  4.595120   4.646491

# %%
regression_model.score(X_train,y_train) #Accuracy
# Out:
# 0.502716441089887

# %%
from sklearn.metrics import mean_absolute_error
print(mean_absolute_error(y_test,y_predicted)) #Average Magnitude of Individual Errors
# Out:
# 0.40611911834279185

# %% [markdown]
# ### Decision Tree

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3,random_state=1)

# %%
dct_model = DecisionTreeRegressor(random_state=1)

# %%
dct_model.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor(random_state=1)

# %%
# Predicting y values using the test set
y_predicted = dct_model.predict(X_test)

# Ensure y_test and y_predicted are arrays
y_test = y_test.values.flatten()
y_predicted = y_predicted.flatten()

# Comparing y_predicted to y_test
comparison = pd.DataFrame({'Actual': y_test, 'Predicted': y_predicted})
print(comparison.head())
# Out:
#      Actual  Predicted
# 0  5.402677   5.498364
# 1  4.867534   4.820378
# 2  4.174387   4.197644
# 3  4.779123   4.382027
# 4  4.787492   4.814768

# %%
dct_model.score(X_train, y_train) #Accuracy, how will the Regression Line fits the Data Points
# Out:
# 0.7146631305240763

# %%
print(mean_absolute_error(y_test,y_predicted)) # Mean Absolute Error
# Out:
# 0.4580364908656312

# %% [markdown]
# Any one is encouraged to apply Regression Model on other 5 Data Sets!
